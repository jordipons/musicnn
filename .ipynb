# %%
# a bunch of imports useless imports for the notebook
import sys
sys.path.append('./musically_motivated_CNN/')
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
from musically_motivated_CNN import musiCNN
taggram, tags = musiCNN.predict(file_name='./audio/TRWJAZW128F42760DD_test.mp3', model='MTT')
# Out:
# input: <bound method Tensor.get_shape of <tf.Tensor 'model_6/Placeholder:0' shape=(?, 187, 96) dtype=float32>>
# input_layer:  (?, 187, 96, 1)
# Output timbral block:  (?, 187, 204)
# Output timbral block:  (?, 187, 204)
# Output tempo-variant block:  (?, 187, 51)
# Output tempo-variant block:  (?, 187, 51)
# Output tempo-variant block:  (?, 187, 51)
# 7774timbraltemporal
# Input to backend: <bound method Tensor.get_shape of <tf.Tensor 'model_6/ExpandDims_1:0' shape=(?, 187, 561, 1) dtype=float32>>
# Dense
# concat_front_end (?, 187, 753, 1)
# Max/Avg pooling
# flat_pool (?, 1506)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#
# ...

# %%
# From the taggram one can estimate the most popular tags
topN = 3
tags_likelihood_mean = np.mean(taggram, axis=0)
print(file_name)
for tag_index in tags_likelihood_mean.argsort()[-topN:][::-1]:
    print(' - [mean] ' + tags[tag_index])
